# %%
"""
Example using Pandas with the Titanic dataset.
"""

import pandas as pd

from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("1M_rows_test_uncompressed.csv")

report = ProfileReport(df)

# %%
report
# Out:
# Summarize dataset:  22%|██▏       | 4/18 [00:03<00:09,  1.49it/s, Describe variable: int_col]      /Users/alvaro/repos/pysuricata/.venv/lib/python3.13/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /Users/alvaro/repos/pysuricata/.venv/lib/python3.13/site-packages/numpy/_core/_methods.py:173: RuntimeWarning: invalid value encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# Summarize dataset:  44%|████▍     | 8/18 [00:04<00:04,  2.49it/s, Describe variable: int_col]/Users/alvaro/repos/pysuricata/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4620: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# ...
