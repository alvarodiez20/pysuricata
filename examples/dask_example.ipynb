# %%
"""
Example using Dask with the Titanic dataset.
"""
import requests
import dask.dataframe as dd
from suricata import generate_report

from IPython.display import HTML


TITANIC_URL = (
    "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
)

# %%
titanic_ddf = dd.read_csv(TITANIC_URL)
html_report = generate_report(titanic_ddf, output_file="titanic_dask_report.html")
print("Dask report saved as 'titanic_dask_report.html'")
HTML(html_report)
# Out:
# INFO:suricata.logger:summary_statistics executed in 0.1398 seconds
# INFO:suricata.logger:missing_values executed in 0.0681 seconds
# INFO:suricata.logger:correlation_matrix executed in 0.0484 seconds
# Dask report saved as 'titanic_dask_report.html'
#     <html>
#       <head>
#         <title>EDA Report</title>
#       </head>
#       <body>
#         <h1>Summary Statistics</h1>
#         <table border="1" class="dataframe table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>survived</th>
#       <th>pclass</th>
#       <th>age</th>
#       <th>sibsp</th>
#       <th>parch</th>
#       <th>fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>714.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.383838</td>
#       <td>2.308642</td>
# ...
